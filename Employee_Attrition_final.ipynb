# %%
#Load the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the data set
df=pd.read_csv('Attrition data (1).csv')
df.head()
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0           1   51        No      Travel_Rarely                   Sales
# 1           2   31       Yes  Travel_Frequently  Research & Development
# 2           3   32        No  Travel_Frequently  Research & Development
# 3           4   38        No         Non-Travel  Research & Development
# 4           5   32        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 0                 6          2  Life Sciences              1  Female  ...
# 1                10          1  Life Sciences              1  Female  ...
# 2                17          4          Other              1    Male  ...
# 3                 2          5  Life Sciences              1    Male  ...
# 4                10          1        Medical              1    Male  ...
#
#    TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# ...

# %%
df.shape
# Out:
# (4410, 29)

# %%
df.describe()
# Out:
#         EmployeeID          Age  DistanceFromHome    Education  EmployeeCount  \
# count  4410.000000  4410.000000       4410.000000  4410.000000         4410.0
# mean   2205.500000    36.923810          9.192517     2.912925            1.0
# std    1273.201673     9.133301          8.105026     1.023933            0.0
# min       1.000000    18.000000          1.000000     1.000000            1.0
# 25%    1103.250000    30.000000          2.000000     2.000000            1.0
# 50%    2205.500000    36.000000          7.000000     3.000000            1.0
# 75%    3307.750000    43.000000         14.000000     4.000000            1.0
# max    4410.000000    60.000000         29.000000     5.000000            1.0
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %%
#check for null values
df.isnull().sum()
# Out:
# EmployeeID                  0
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# JobInvolvement              0
# PerformanceRating           0
# dtype: int64

# %%
#handel the missing values by filling with 0 or mean value
df['NumCompaniesWorked'].fillna(0,inplace=True)
df['EnvironmentSatisfaction'].fillna(df['EnvironmentSatisfaction'].mean(),inplace=True)
df['JobSatisfaction'].fillna(df['JobSatisfaction'].mean(),inplace=True)
df['WorkLifeBalance'].fillna(df['WorkLifeBalance'].mean(),inplace=True)

# %%
df['WorkLifeBalance']= df['WorkLifeBalance'].round(1)

# %%
attrition_count = pd.DataFrame(df['Attrition'].value_counts())
attrition_count
# Out:
#      Attrition
# No        3699
# Yes        711

# %%
# pie plot for attrition % age
plt.pie(attrition_count['Attrition'] , labels = ['No' , 'Yes'] , explode = (0.2,0), autopct='%1.1f%%')
plt.title('Attrition Distribution')
plt.show()

# %%
# number of employees by attrition status
sns.countplot(df['Attrition'], palette='Set2') 
plt.xlabel('Attrition Status')
plt.ylabel('Number of Employees')
plt.title('Count of Employees by Attrition Status')

for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.show()
# Out:
# C:\Users\shock\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Removing unnessesary columns
df.drop(['EmployeeCount' , 'StandardHours','Over18'] , axis = 1)
# Out:
#       EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0              1   51        No      Travel_Rarely                   Sales
# 1              2   31       Yes  Travel_Frequently  Research & Development
# 2              3   32        No  Travel_Frequently  Research & Development
# 3              4   38        No         Non-Travel  Research & Development
# 4              5   32        No      Travel_Rarely  Research & Development
# ...          ...  ...       ...                ...                     ...
# 4405        4406   42        No      Travel_Rarely  Research & Development
# 4406        4407   29        No      Travel_Rarely  Research & Development
# 4407        4408   25        No      Travel_Rarely  Research & Development
# 4408        4409   42        No      Travel_Rarely                   Sales
# 4409        4410   40        No      Travel_Rarely  Research & Development
#
# ...

# %%
attrition_dummies = pd.get_dummies(df['Attrition'])
attrition_dummies.head()
# Out:
#    No  Yes
# 0   1    0
# 1   0    1
# 2   1    0
# 3   1    0
# 4   1    0

# %%
df = pd.concat([df, attrition_dummies] , axis = 1)
df.head()
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0           1   51        No      Travel_Rarely                   Sales
# 1           2   31       Yes  Travel_Frequently  Research & Development
# 2           3   32        No  Travel_Frequently  Research & Development
# 3           4   38        No         Non-Travel  Research & Development
# 4           5   32        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 0                 6          2  Life Sciences              1  Female  ...
# 1                10          1  Life Sciences              1  Female  ...
# 2                17          4          Other              1    Male  ...
# 3                 2          5  Life Sciences              1    Male  ...
# 4                10          1        Medical              1    Male  ...
#
#    YearsAtCompany YearsSinceLastPromotion YearsWithCurrManager  \
# ...

# %%
df = df.drop(['Attrition' , 'No'] , axis = 1)
df.head()
# Out:
#    EmployeeID  Age     BusinessTravel              Department  \
# 0           1   51      Travel_Rarely                   Sales
# 1           2   31  Travel_Frequently  Research & Development
# 2           3   32  Travel_Frequently  Research & Development
# 3           4   38         Non-Travel  Research & Development
# 4           5   32      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  \
# 0                 6          2  Life Sciences              1  Female
# 1                10          1  Life Sciences              1  Female
# 2                17          4          Other              1    Male
# 3                 2          5  Life Sciences              1    Male
# 4                10          1        Medical              1    Male
#
#    JobLevel  ... TrainingTimesLastYear YearsAtCompany  \
# 0         1  ...                     6              1
# 1         1  ...                     3              5
# ...

# %%
sns.barplot(x = 'Gender' , y = 'Yes', data = df)

plt.xlabel('Gender')
plt.ylabel('Number of "Attrition"')
plt.title('Number of "Attrition" by Gender')
plt.show()

# %%
sns.barplot(x = 'Department', y = 'Yes', data = df)
plt.xlabel('Department')
plt.ylabel('Number of "Attrition"')
plt.title('Number of "Attrition" by Department')
plt.show()

# %%
sns.barplot(x = 'BusinessTravel', y = 'Yes', data = df)
plt.xlabel('Business Travel')
plt.ylabel('Number of "Attrition"')
plt.title('Number of "Attrition" by Business Travel')
plt.show()

# %%
# Coorelation matrix
correlation_matrix = df.corr()
plt.figure(figsize=(20, 20))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
sns.histplot(df['Age'], kde=True, color='skyblue')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age with KDE')
plt.axvline(df['Age'].median(), color='red', linestyle='dashed', linewidth=1.5, label='Median Age')  # Add median line
plt.axvline(df['Age'].mean(), color='orange', linestyle='dashed', linewidth=1.5, label='Mean Age')   # Add mean line
plt.legend()  
plt.grid(True)  
plt.show()
